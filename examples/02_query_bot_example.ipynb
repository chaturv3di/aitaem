# %% [markdown]
# QueryBot example — Global Ads Performance dataset.
#
# Demonstrates a multi-turn conversation with QueryBot using the ad campaign
# dataset bundled in examples/data/.  Each turn shows the agent's narrative,
# the assembled payload, and a preview of the underlying Arrow result.
#
# Prerequisites
# -------------
# 1. Create the DuckDB database (one-time setup):
#        `python examples/data/setup_db.py`
#
# 2. Set your Anthropic API key:
#        `export ANTHROPIC_API_KEY=sk-ant-...`
#
# 3. Install the agent extra:
#        `pip install aitaem[agent-anthropic]`

# %% [markdown]
# Set the path to the local folder which contains your AITAEM examples. The following subfolders are needed inside of `aitaem_folder_path`:
# * `data`
# * `metrics`
# * `slices`

# %%
aitaem_folder_path = "path/to/aitaem" #e.g. "/Users/you/Workspace/aitaem"

# %%
import sys
import importlib

sys.path.insert(0, aitaem_folder_path + "/examples")
ex = importlib.import_module("02_query_bot_example")

# %%
await ex.main(base_path=aitaem_folder_path, exit_on_missing_key=False)
# Out:
# Loading specs …
#   6 metrics: avg_revenue, campaign_count, ctr, max_revenue, roas, total_revenue
#   3 slices : campaign_type, geo, industry
#
# Starting conversation …
#
# ──────────────────────────────────────────────────────────────────────
# Turn 1: What was the total revenue and ROAS across all campaigns?
# ──────────────────────────────────────────────────────────────────────
# Status   : ok
# Narrative: Across all campaigns:  - **Total Revenue**: $54,183,330.81 - **ROAS
#            (Return on Ad Spend)**: 4.88 — meaning for every dollar
#            spent on ads, you generated $4.88 in revenue.
# Metrics  : total_revenue, roas
# Slices   : —
# Period   : all_time
# Results  : 2 result(s)  primary=1e459b16-e9e5-4e4d-a180-6a6cc9ff9795
#
# Sample (1 row(s)):
# period_type   metric_name slice_type slice_value segment_name segment_value  metric_value
#    all_time total_revenue       none         all         none           all   54183330.81
#
# Trace    : run=019f91a1  conv=019f91a1  5273ms
#   ✓ record_intent(metric_concept='total re…', scope='overall')
#   ✓ record_intent(metric_concept='ROAS', scope='overall')
#   ✓ resolve_intent(intent_id=0, metric_name='total_re…')
#   ✓ resolve_intent(intent_id=1, metric_name='roas')
#   ✓ compute_metrics(spec_token='sm_852ca…')
#   ✓ compute_metrics(spec_token='sm_825f7…')
#   ✓ final_result(status='ok', narrative='Across a…', result_ids=['1e459b16-e9e5-4e4d-a180-6a6cc9ff9795', '9b9cccbe-0c38-4c88-a68c-8b0d29dae52b'])
# Tokens   : 20954 in / 538 out  (21492 total)
#
# ──────────────────────────────────────────────────────────────────────
# Turn 2: Which campaign type had the highest CTR?
# ──────────────────────────────────────────────────────────────────────
# Status   : ok
# Narrative: **Search** campaigns had the highest CTR at **3.99%**, outperforming
#            Video (3.79%), Shopping (3.84%), and Display (3.77%)
#            campaign types.
# Metrics  : ctr
# Slices   : campaign_type
# Period   : all_time
# Results  : 1 result(s)  primary=3a68de1b-4e9d-4b3d-b28b-965e9b57f0a5
#
# Trace    : run=019f91a2  conv=019f91a1  8532ms
#   ✓ record_intent(metric_concept='click-th…', scope='subset', slice_type='campaign…')
#   ✓ resolve_intent(intent_id=0, metric_name='ctr', slices=['campaign_type'])
#   ✓ compute_metrics(spec_token='sm_9cca1…')
#   ✓ rank_by_value(result_id='a58406a0…', top_n=1)
#   ✓ final_result(status='ok', narrative='**Search…', result_ids=['3a68de1b-4e9d-4b3d-b28b-965e9b57f0a5'])
# Tokens   : 35460 in / 452 out  (35912 total)
#
# ──────────────────────────────────────────────────────────────────────
# Turn 3: How did total revenue change between H1 2024 (Jan–Jun) and H2 2024 (Jul–Dec)?
# ──────────────────────────────────────────────────────────────────────
# Status   : ok
# Narrative: Based on monthly data for 2024:  **H1 2024 (Jan–Jun) Total Revenue**:
#            $26,379,706.41  **H2 2024 (Jul–Dec) Total Revenue**:
#            $27,803,624.39  **Change**: H2 2024 showed an increase of
#            $1,423,917.98 (+5.4%) compared to H1 2024, indicating
#            growing revenue momentum in the second half of the year.
#            December was particularly strong at $5,159,353.33, the
#            highest monthly revenue of the year.
# Metrics  : total_revenue
# Slices   : —
# Period   : monthly  2024-01-01 → 2024-12-31
# Results  : 1 result(s)  primary=f41cf13c-7641-47a7-8340-4ce6920a5da1
#
# Sample (5 row(s)):
# period_type   period_start_date     period_end_date   metric_name slice_type slice_value segment_name segment_value  metric_value
#     monthly 2024-03-01 00:00:00 2024-04-01 00:00:00 total_revenue       none         all         none           all    4407519.38
#     monthly 2024-01-01 00:00:00 2024-02-01 00:00:00 total_revenue       none         all         none           all    4691994.47
#     monthly 2024-12-01 00:00:00 2025-01-01 00:00:00 total_revenue       none         all         none           all    5159353.33
#     monthly 2024-06-01 00:00:00 2024-07-01 00:00:00 total_revenue       none         all         none           all    4362176.31
#     monthly 2024-11-01 00:00:00 2024-12-01 00:00:00 total_revenue       none         all         none           all    4484002.75
#
# Trace    : run=019f91a2  conv=019f91a1  6205ms
#   ✓ record_intent(metric_concept='total re…', scope='overall', period_type='monthly', time_window=['2024-01-01', '2024-12-31'])
#   ✓ resolve_intent(intent_id=0, metric_name='total_re…')
#   ✓ compute_metrics(spec_token='sm_6b315…')
#   ✓ final_result(status='ok', narrative='Based on…', result_ids=['f41cf13c-7641-47a7-8340-4ce6920a5da1'])
# Tokens   : 35147 in / 455 out  (35602 total)
#
# ──────────────────────────────────────────────────────────────────────
# Session  : conv=019f91a1  3 turns  93006 tokens
# Done.
